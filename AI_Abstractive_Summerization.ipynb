# %% [markdown]
# # Install dependencies
#
# - install PyTorch
# - install Transformers

# %%
# !pip install torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install transformers

# %% [markdown]
# # Import & load model
#
# - import dependencies
# - load tokenizer
# - load model

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# %%
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")
# Out:
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]

# %% [markdown]
# # Perform abstractive summerization
#
# - create tokens (number presentation of our text)
# - summarize (get summary in tokens)
# - decode summary

# %%
text = """
It’s no secret that decision tree-based models excel at a wide range of classification and regression tasks, often based on structured, tabular data. However,
 when combined with the right tools, decision trees also become powerful predictive tools for unstructured data,
 such as text or images, and even time series data.
This article demonstrates how to build decision trees for text data. Specifically, we will incorporate text representation techniques like TF-IDF and embeddings in
 decision trees trained for spam email classification, evaluating their performance and comparing the results with another text classification model —
 all with the aid of Python’s Scikit-learn library.
"""

# %%
tokens = tokenizer(text, truncation=True, padding="longest", return_tensors="pt")
coded_summary = model.generate(**tokens)
decoded_summary = tokenizer.decode(coded_summary[0])

# %%
print(f'============== Tokens Generated form Our Text Input ==============\n{tokens}')
print(f'\n============== Abstract Summary In Tokens ==============\n{coded_summary}')
print(f'\n============== Decoded Abstract Summary ==============\n{decoded_summary}')
# Out:
# ============== Tokens Generated form Our Text Input ==============
# {'input_ids': tensor([[  168,   123,   116,   220,  3235,   120,  1057,  1681,   121,   936,
#           1581,  8519,   134,   114,   827,   499,   113, 10526,   111, 19363,
#           2722,   108,   432,   451,   124,  7314,   108, 78448,   335,   107,
#            611,   108,   173,  2211,   122,   109,   268,   977,   108,  1057,
#           2115,   163,   460,  1512, 18652,   977,   118, 41831,   335,   108,
#            253,   130,  1352,   132,  1055,   108,   111,   254,   166,   679,
#            335,   107,   182,   974,  9126,   199,   112,   736,  1057,  2115,
#            118,  1352,   335,   107, 16736,   108,   145,   138,  5289,  1352,
#           5114,  1739,   172, 25016,   121,   187, 17236,   111, 35727,   116,
#            115,  1057,  2115,  2492,   118,  9168,   643, 10526,   108, 10780,
#            153,   637,   111,  8633,   109,   602,   122,   372,  1352, 10526,
# ...
